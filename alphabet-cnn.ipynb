# %% [markdown]
# # **Name: Md. Azharul Islam <br>
# # ID: 181-35-2329**

# %%
#import all the libraries
import os
import string

import numpy as np
import torch
import torch.nn as nn
from torch.nn import functional as F
from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler

import torchvision
#from torchvision import models
from torchvision import transforms
from torchvision.transforms import ToTensor, Normalize

# %%
#ord('C') - ord('A')

# %%
#Train dataset config 
# Two mappings have been made here. 
#The first is from charachter to integer and the second is from integer to charachter. So first I did integer mapping from charachter.
class ASLDatasetTrain(Dataset):
    char_to_int = {c: ord(c) - ord('A') for c in string.ascii_uppercase} #I have created a dictionary here.
    char_to_int['del'] = 26
    char_to_int['nothing'] = 27
    char_to_int['space'] = 28
    int_to_char = {value: key for key, value in char_to_int.items()}
    #asci_uppercase mainly return the all upper case alphabet and i take e key value. Suppose if the alphabet 'A' then the outcome is zero.
    #More explanation suppose if you run ord('A') then you get the A alphabet value but we need to sort out of all the values so 
    #what we've done here is we've got a key value for each alphabet.
    #Where the value of A is zero then the value of B continuously is 2 and thus I have taken 26 key values of 26 alphabets.
    #And thats the way to get the each key value - ord('B') - ord('A')
    #Since I have taken the key value of our 27 alphabets as 26 (0-25), 
    #on the other hand I had 3 extra classes and I have taken those 3 classes as 26, 27, 28 respectively.
    #And finally i convert to integer value to character value.
        
    def __init__(self, directory: str, transform=None, label_transform=None):
        #I have given some parameters here where I have set the directory which means I have input the directory in which I have the dataset. 
        #Then I did no transformation for the dataset and did the label transformation none.
        super().__init__()
        
        self.directory = directory #Since I have created separate functions for train and test, I have just given a directory here.
        self.transform = transform
        self.label_transform = label_transform
        
        self.x = None
        self.y = None
        # This portion I am setting the data as none and also setting the target as none.
        self._load_images()
        #And finally i call my helper function.
    
    def __getitem__(self, idx):
        x, y = torchvision.io.read_image(self.x[idx]).type(torch.float32), self.y[idx]
        
        if self.transform:
            x = self.transform(x)
        if self.label_transform:
            y = self.label_transform(y)
        
        return x, y
    
    def __len__(self):
        return len(self.y)
    
    def _load_images(self):
        self.x = []
        self.y = []
        
        for c in os.listdir(self.directory):
            class_name = c
            class_dir = os.path.join(self.directory, class_name)
            for img in os.listdir(class_dir):
                self.x.append(os.path.join(class_dir, img))
                self.y.append(self.char_to_int[class_name])
                
        self.y = torch.tensor(self.y, dtype=torch.int64)
    #I set the directory which is train or test, whatever it is, I will run a loop in all the folders. 
    #I am running a list of all the folders that I have set in self.directory. We can see from the dataset that the name of the directory is the class name. 
    #Then the class name will be (C). Then we enter the class directory and return all the files / folders in that directory.
    #At the end of in the load image function, 
    #all image paths are being stored in self.x and all image labels are being stored in self.y.
    @staticmethod
    def get_classname(idx: int) -> str:
        return ASLDatasetTrain.int_to_char[idx] # This function mainly work, suppose if you take (0) id then it returns alphabet (A) mainly this function return integer to charachter value.

# %%
#Test dataset config
class ASLDatasetTest(Dataset):
    char_to_int = {c: ord(c) - ord('A') for c in string.ascii_uppercase}
    char_to_int['del'] = 26
    char_to_int['nothing'] = 27
    char_to_int['space'] = 28
    int_to_char = {value: key for key, value in char_to_int.items()}
        
    def __init__(self, directory: str, transform=None, label_transform=None):
        super().__init__()
        
        self.directory = directory
        self.transform = transform
        self.label_transform = label_transform
        
        self.x = None
        self.y = None
        
        self._load_images()
    
    def __getitem__(self, idx):
        x, y = torchvision.io.read_image(self.x[idx]).type(torch.float32), self.y[idx]
        
        if self.transform:
            x = self.transform(x)
        if self.label_transform:
            y = self.label_transform(y)
        
        return x, y
    
    def __len__(self):
        return len(self.y)
    
    def _load_images(self):
        self.x = []
        self.y = []
        
        for img in os.listdir(self.directory):
            class_name = img [:1]
            if 'space' in img:
                class_name = 'space'
            elif 'nothing' in img:
                class_name = 'nothing'
            elif 'del' in img:
                class_name = 'del'    
            self.x.append(os.path.join(self.directory, img))
            self.y.append(self.char_to_int[class_name])
                
        self.y = torch.tensor(self.y, dtype=torch.int64)
    
    @staticmethod
    def get_classname(idx: int) -> str:
        return ASLDatasetTest.int_to_char[idx]
    #The DatasetTest function will work the same as the DatasetTrain function, but the load image function will change a bit because my test dataset was a little different. 
    #The test dataset contained all the images in a folder, so I used a condition in the load image function. 
    #In that condition if the name of the image is 'space', 'nothing' or 'dell' then the class name will be 'space', 'nothing' or 'dell'.

# %%
#Transformation
ts = transforms.Compose([
    transforms.Resize(256),
    transforms.RandomCrop(224),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
])
#Here's what I think, 
#resize has taken more than the required size of an image here (256) and taken randomly (224).
#And also i think that are ratio issues thats why use the size 256.
#Since I am using AlexNet, this value works best to normalize so I am using it.

# %%
#All the data store in train and test
train = ASLDatasetTrain('../input/fingerdataset/dataset/train', transform=ts)
test = ASLDatasetTest('../input/fingerdataset/dataset/test', transform=ts)
#Now we will load the data as my test dataset is different so I have taken two functions to load.

# %%
#Train and test data print
print(len(train))
print(len(test))
# Out:
# 812
# 203

# %%
#test path
test.x
#to check the each data
# Out:
# ['../input/fingerdataset/dataset/test/O2112.jpg',
#  '../input/fingerdataset/dataset/test/L2080.jpg',
#  '../input/fingerdataset/dataset/test/G331.jpg',
#  '../input/fingerdataset/dataset/test/T1452.jpg',
#  '../input/fingerdataset/dataset/test/W575.jpg',
#  '../input/fingerdataset/dataset/test/Q2011.jpg',
#  '../input/fingerdataset/dataset/test/I2044.jpg',
#  '../input/fingerdataset/dataset/test/V1796.jpg',
#  '../input/fingerdataset/dataset/test/F1236.jpg',
#  '../input/fingerdataset/dataset/test/F1804.jpg',
#  '../input/fingerdataset/dataset/test/R1048.jpg',
#  '../input/fingerdataset/dataset/test/H1828.jpg',
#  '../input/fingerdataset/dataset/test/A644.jpg',
#  '../input/fingerdataset/dataset/test/W1143.jpg',
#  '../input/fingerdataset/dataset/test/C691.jpg',
#  '../input/fingerdataset/dataset/test/nothing324.jpg',
#  '../input/fingerdataset/dataset/test/W1303.jpg',
#  '../input/fingerdataset/dataset/test/X2276.jpg',
#  '../input/fingerdataset/dataset/test/Y2124.jpg',
#  '../input/fingerdataset/dataset/test/Q8.jpg',
#  '../input/fingerdataset/dataset/test/del16.jpg',
#  '../input/fingerdataset/dataset/test/P2324.jpg',
#  '../input/fingerdataset/dataset/test/T908.jpg',
#  '../input/fingerdataset/dataset/test/J592.jpg',
#  '../input/fingerdataset/dataset/test/O1168.jpg',
#  '../input/fingerdataset/dataset/test/H2588.jpg',
#  '../input/fingerdataset/dataset/test/J384.jpg',
#  '../input/fingerdataset/dataset/test/L1532.jpg',
#  '../input/fingerdataset/dataset/test/K468.jpg',
#  '../input/fingerdataset/dataset/test/B852.jpg',
#  '../input/fingerdataset/dataset/test/D8.jpg',
#  '../input/fingerdataset/dataset/test/N2516.jpg',
#  '../input/fingerdataset/dataset/test/D1860.jpg',
#  '../input/fingerdataset/dataset/test/N1276.jpg',
#  '../input/fingerdataset/dataset/test/B375.jpg',
#  '../input/fingerdataset/dataset/test/del1996.jpg',
#  '../input/fingerdataset/dataset/test/C1742.jpg',
#  '../input/fingerdataset/dataset/test/P1220.jpg',
#  '../input/fingerdataset/dataset/test/N776.jpg',
#  '../input/fingerdataset/dataset/test/H248.jpg',
#  '../input/fingerdataset/dataset/test/M2632.jpg',
#  '../input/fingerdataset/dataset/test/O8.jpg',
#  '../input/fingerdataset/dataset/test/D831.jpg',
#  '../input/fingerdataset/dataset/test/D1768.jpg',
#  '../input/fingerdataset/dataset/test/Y1124.jpg',
#  '../input/fingerdataset/dataset/test/H2139.jpg',
#  '../input/fingerdataset/dataset/test/W8.jpg',
#  '../input/fingerdataset/dataset/test/F12.jpg',
#  '../input/fingerdataset/dataset/test/T8.jpg',
#  '../input/fingerdataset/dataset/test/X432.jpg',
#  '../input/fingerdataset/dataset/test/space644.jpg',
#  '../input/fingerdataset/dataset/test/A856.jpg',
#  '../input/fingerdataset/dataset/test/W2531.jpg',
#  '../input/fingerdataset/dataset/test/E8.jpg',
#  '../input/fingerdataset/dataset/test/space2212.jpg',
#  '../input/fingerdataset/dataset/test/Q1707.jpg',
#  '../input/fingerdataset/dataset/test/V896.jpg',
#  '../input/fingerdataset/dataset/test/U832.jpg',
#  '../input/fingerdataset/dataset/test/X8.jpg',
#  '../input/fingerdataset/dataset/test/R2623.jpg',
#  '../input/fingerdataset/dataset/test/G1692.jpg',
#  '../input/fingerdataset/dataset/test/B2341.jpg',
#  '../input/fingerdataset/dataset/test/I1148.jpg',
#  '../input/fingerdataset/dataset/test/space956.jpg',
#  '../input/fingerdataset/dataset/test/I599.jpg',
#  '../input/fingerdataset/dataset/test/U2176.jpg',
#  '../input/fingerdataset/dataset/test/G856.jpg',
#  '../input/fingerdataset/dataset/test/M708.jpg',
#  '../input/fingerdataset/dataset/test/Z208.jpg',
#  '../input/fingerdataset/dataset/test/E1436.jpg',
#  '../input/fingerdataset/dataset/test/space2652.jpg',
#  '../input/fingerdataset/dataset/test/M2068.jpg',
#  '../input/fingerdataset/dataset/test/L8.jpg',
#  '../input/fingerdataset/dataset/test/E2034.jpg',
#  '../input/fingerdataset/dataset/test/R676.jpg',
#  '../input/fingerdataset/dataset/test/Y936.jpg',
#  '../input/fingerdataset/dataset/test/C692.jpg',
#  '../input/fingerdataset/dataset/test/B376.jpg',
#  '../input/fingerdataset/dataset/test/N1740.jpg',
#  '../input/fingerdataset/dataset/test/X1992.jpg',
#  '../input/fingerdataset/dataset/test/V2580.jpg',
#  '../input/fingerdataset/dataset/test/I255.jpg',
#  '../input/fingerdataset/dataset/test/L2964.jpg',
#  '../input/fingerdataset/dataset/test/S148.jpg',
#  '../input/fingerdataset/dataset/test/C336.jpg',
#  '../input/fingerdataset/dataset/test/A2145.jpg',
#  '../input/fingerdataset/dataset/test/space1908.jpg',
#  '../input/fingerdataset/dataset/test/L1108.jpg',
#  '../input/fingerdataset/dataset/test/H1136.jpg',
#  '../input/fingerdataset/dataset/test/del2102.jpg',
#  '../input/fingerdataset/dataset/test/X1408.jpg',
#  '../input/fingerdataset/dataset/test/D1144.jpg',
#  '../input/fingerdataset/dataset/test/W224.jpg',
#  '../input/fingerdataset/dataset/test/L808.jpg',
#  '../input/fingerdataset/dataset/test/V2204.jpg',
#  '../input/fingerdataset/dataset/test/Z608.jpg',
#  '../input/fingerdataset/dataset/test/A6.jpg',
#  '../input/fingerdataset/dataset/test/W2076.jpg',
#  '../input/fingerdataset/dataset/test/del1943.jpg',
#  '../input/fingerdataset/dataset/test/A1068.jpg',
#  '../input/fingerdataset/dataset/test/F2600.jpg',
#  '../input/fingerdataset/dataset/test/K272.jpg',
#  '../input/fingerdataset/dataset/test/V1472.jpg',
#  '../input/fingerdataset/dataset/test/F1480.jpg',
#  '../input/fingerdataset/dataset/test/nothing2632.jpg',
#  '../input/fingerdataset/dataset/test/N8.jpg',
#  '../input/fingerdataset/dataset/test/N172.jpg',
#  '../input/fingerdataset/dataset/test/P2172.jpg',
#  '../input/fingerdataset/dataset/test/O1976.jpg',
#  '../input/fingerdataset/dataset/test/K560.jpg',
#  '../input/fingerdataset/dataset/test/V460.jpg',
#  '../input/fingerdataset/dataset/test/M864.jpg',
#  '../input/fingerdataset/dataset/test/nothing2212.jpg',
#  '../input/fingerdataset/dataset/test/V8.jpg',
#  '../input/fingerdataset/dataset/test/K1024.jpg',
#  '../input/fingerdataset/dataset/test/K2924.jpg',
#  '../input/fingerdataset/dataset/test/T1912.jpg',
#  '../input/fingerdataset/dataset/test/B8.jpg',
#  '../input/fingerdataset/dataset/test/R396.jpg',
#  '../input/fingerdataset/dataset/test/S2732.jpg',
#  '../input/fingerdataset/dataset/test/G8.jpg',
#  '../input/fingerdataset/dataset/test/Q467.jpg',
#  '../input/fingerdataset/dataset/test/nothing96.jpg',
#  '../input/fingerdataset/dataset/test/F432.jpg',
#  '../input/fingerdataset/dataset/test/E360.jpg',
#  '../input/fingerdataset/dataset/test/I1568.jpg',
#  '../input/fingerdataset/dataset/test/Z1336.jpg',
#  '../input/fingerdataset/dataset/test/nothing156.jpg',
#  '../input/fingerdataset/dataset/test/X2252.jpg',
#  '../input/fingerdataset/dataset/test/O664.jpg',
#  '../input/fingerdataset/dataset/test/P2712.jpg',
#  '../input/fingerdataset/dataset/test/U1800.jpg',
#  '../input/fingerdataset/dataset/test/A643.jpg',
#  '../input/fingerdataset/dataset/test/A855.jpg',
#  '../input/fingerdataset/dataset/test/P184.jpg',
#  '../input/fingerdataset/dataset/test/Z64.jpg',
#  '../input/fingerdataset/dataset/test/P1824.jpg',
#  '../input/fingerdataset/dataset/test/C1172.jpg',
#  '../input/fingerdataset/dataset/test/R8.jpg',
#  '../input/fingerdataset/dataset/test/P536.jpg',
#  '../input/fingerdataset/dataset/test/I8.jpg',
#  '../input/fingerdataset/dataset/test/U1384.jpg',
#  '../input/fingerdataset/dataset/test/H236.jpg',
#  '../input/fingerdataset/dataset/test/T2268.jpg',
#  '../input/fingerdataset/dataset/test/E912.jpg',
#  '../input/fingerdataset/dataset/test/S1348.jpg',
#  '../input/fingerdataset/dataset/test/K1536.jpg',
#  '../input/fingerdataset/dataset/test/J1516.jpg',
#  '../input/fingerdataset/dataset/test/U2660.jpg',
#  '../input/fingerdataset/dataset/test/Y12.jpg',
#  '../input/fingerdataset/dataset/test/space8.jpg',
#  '../input/fingerdataset/dataset/test/R2067.jpg',
#  '../input/fingerdataset/dataset/test/del716.jpg',
#  '../input/fingerdataset/dataset/test/X968.jpg',
#  '../input/fingerdataset/dataset/test/U2500.jpg',
#  '../input/fingerdataset/dataset/test/S2020.jpg',
#  '../input/fingerdataset/dataset/test/U8.jpg',
#  '../input/fingerdataset/dataset/test/M544.jpg',
#  '../input/fingerdataset/dataset/test/B1004.jpg',
#  '../input/fingerdataset/dataset/test/N412.jpg',
#  '../input/fingerdataset/dataset/test/Y1419.jpg',
#  '../input/fingerdataset/dataset/test/H8.jpg',
#  '../input/fingerdataset/dataset/test/O576.jpg',
#  '../input/fingerdataset/dataset/test/M1604.jpg',
#  '../input/fingerdataset/dataset/test/O2716.jpg',
#  '../input/fingerdataset/dataset/test/space1772.jpg',
#  '../input/fingerdataset/dataset/test/C8.jpg',
#  '../input/fingerdataset/dataset/test/E2555.jpg',
#  '../input/fingerdataset/dataset/test/Y447.jpg',
#  '../input/fingerdataset/dataset/test/B1434.jpg',
#  '../input/fingerdataset/dataset/test/S416.jpg',
#  '../input/fingerdataset/dataset/test/Q1239.jpg',
#  '../input/fingerdataset/dataset/test/T2544.jpg',
#  '../input/fingerdataset/dataset/test/Y240.jpg',
#  '../input/fingerdataset/dataset/test/J1316.jpg',
#  '../input/fingerdataset/dataset/test/J2296.jpg',
#  '../input/fingerdataset/dataset/test/K8.jpg',
#  '../input/fingerdataset/dataset/test/D924.jpg',
#  '../input/fingerdataset/dataset/test/nothing508.jpg',
#  '../input/fingerdataset/dataset/test/Z808.jpg',
#  '../input/fingerdataset/dataset/test/J2832.jpg',
#  '../input/fingerdataset/dataset/test/del2928.jpg',
#  '../input/fingerdataset/dataset/test/S740.jpg',
#  '../input/fingerdataset/dataset/test/R1352.jpg',
#  '../input/fingerdataset/dataset/test/G396.jpg',
#  '../input/fingerdataset/dataset/test/C2372.jpg',
#  '../input/fingerdataset/dataset/test/Q2539.jpg',
#  '../input/fingerdataset/dataset/test/D2460.jpg',
#  '../input/fingerdataset/dataset/test/G2660.jpg',
#  '../input/fingerdataset/dataset/test/G1379.jpg',
#  '../input/fingerdataset/dataset/test/del1195.jpg',
#  '../input/fingerdataset/dataset/test/nothing1640.jpg',
#  '../input/fingerdataset/dataset/test/I2584.jpg',
#  '../input/fingerdataset/dataset/test/M8.jpg',
#  '../input/fingerdataset/dataset/test/F663.jpg',
#  '../input/fingerdataset/dataset/test/Z2716.jpg',
#  '../input/fingerdataset/dataset/test/Q900.jpg',
#  '../input/fingerdataset/dataset/test/Z1968.jpg',
#  '../input/fingerdataset/dataset/test/J12.jpg',
#  '../input/fingerdataset/dataset/test/L1816.jpg',
#  '../input/fingerdataset/dataset/test/E1979.jpg',
#  '../input/fingerdataset/dataset/test/T1772.jpg',
#  '../input/fingerdataset/dataset/test/S532.jpg']

# %%
#train path
train.x
#to check the each data
# Out:
# ['../input/fingerdataset/dataset/train/N/N1.jpg',
#  '../input/fingerdataset/dataset/train/N/N2059.jpg',
#  '../input/fingerdataset/dataset/train/N/N2698.jpg',
#  '../input/fingerdataset/dataset/train/N/N531.jpg',
#  '../input/fingerdataset/dataset/train/N/N529.jpg',
#  '../input/fingerdataset/dataset/train/N/N1465.jpg',
#  '../input/fingerdataset/dataset/train/N/N1032.jpg',
#  '../input/fingerdataset/dataset/train/N/N2155.jpg',
#  '../input/fingerdataset/dataset/train/N/N2060.jpg',
#  '../input/fingerdataset/dataset/train/N/N2700.jpg',
#  '../input/fingerdataset/dataset/train/N/N2057.jpg',
#  '../input/fingerdataset/dataset/train/N/N530.jpg',
#  '../input/fingerdataset/dataset/train/N/N1468.jpg',
#  '../input/fingerdataset/dataset/train/N/N2154.jpg',
#  '../input/fingerdataset/dataset/train/N/N1466.jpg',
#  '../input/fingerdataset/dataset/train/N/N1467.jpg',
#  '../input/fingerdataset/dataset/train/N/N3.jpg',
#  '../input/fingerdataset/dataset/train/N/N2153.jpg',
#  '../input/fingerdataset/dataset/train/N/N2699.jpg',
#  '../input/fingerdataset/dataset/train/N/N2058.jpg',
#  '../input/fingerdataset/dataset/train/N/N2.jpg',
#  '../input/fingerdataset/dataset/train/N/N2156.jpg',
#  '../input/fingerdataset/dataset/train/N/N1030.jpg',
#  '../input/fingerdataset/dataset/train/N/N2697.jpg',
#  '../input/fingerdataset/dataset/train/N/N4.jpg',
#  '../input/fingerdataset/dataset/train/N/N1029.jpg',
#  '../input/fingerdataset/dataset/train/N/N532.jpg',
#  '../input/fingerdataset/dataset/train/N/N1031.jpg',
#  '../input/fingerdataset/dataset/train/R/R1249.jpg',
#  '../input/fingerdataset/dataset/train/R/R685.jpg',
#  '../input/fingerdataset/dataset/train/R/R329.jpg',
#  '../input/fingerdataset/dataset/train/R/R331.jpg',
#  '../input/fingerdataset/dataset/train/R/R1251.jpg',
#  '../input/fingerdataset/dataset/train/R/R2091.jpg',
#  '../input/fingerdataset/dataset/train/R/R686.jpg',
#  '../input/fingerdataset/dataset/train/R/R2089.jpg',
#  '../input/fingerdataset/dataset/train/R/R948.jpg',
#  '../input/fingerdataset/dataset/train/R/R4.jpg',
#  '../input/fingerdataset/dataset/train/R/R2647.jpg',
#  '../input/fingerdataset/dataset/train/R/R2092.jpg',
#  '../input/fingerdataset/dataset/train/R/R946.jpg',
#  '../input/fingerdataset/dataset/train/R/R687.jpg',
#  '../input/fingerdataset/dataset/train/R/R332.jpg',
#  '../input/fingerdataset/dataset/train/R/R688.jpg',
#  '../input/fingerdataset/dataset/train/R/R1250.jpg',
#  '../input/fingerdataset/dataset/train/R/R2646.jpg',
#  '../input/fingerdataset/dataset/train/R/R2090.jpg',
#  '../input/fingerdataset/dataset/train/R/R945.jpg',
#  '../input/fingerdataset/dataset/train/R/R330.jpg',
#  '../input/fingerdataset/dataset/train/R/R2.jpg',
#  '../input/fingerdataset/dataset/train/R/R1.jpg',
#  '../input/fingerdataset/dataset/train/R/R2648.jpg',
#  '../input/fingerdataset/dataset/train/R/R2645.jpg',
#  '../input/fingerdataset/dataset/train/R/R947.jpg',
#  '../input/fingerdataset/dataset/train/R/R1252.jpg',
#  '../input/fingerdataset/dataset/train/R/R3.jpg',
#  '../input/fingerdataset/dataset/train/space/space1127.jpg',
#  '../input/fingerdataset/dataset/train/space/space1.jpg',
#  '../input/fingerdataset/dataset/train/space/space168.jpg',
#  '../input/fingerdataset/dataset/train/space/space415.jpg',
#  '../input/fingerdataset/dataset/train/space/space1125.jpg',
#  '../input/fingerdataset/dataset/train/space/space2060.jpg',
#  '../input/fingerdataset/dataset/train/space/space2612.jpg',
#  '../input/fingerdataset/dataset/train/space/space753.jpg',
#  '../input/fingerdataset/dataset/train/space/space413.jpg',
#  '../input/fingerdataset/dataset/train/space/space2609.jpg',
#  '../input/fingerdataset/dataset/train/space/space754.jpg',
#  '../input/fingerdataset/dataset/train/space/space166.jpg',
#  '../input/fingerdataset/dataset/train/space/space167.jpg',
#  '../input/fingerdataset/dataset/train/space/space2.jpg',
#  '../input/fingerdataset/dataset/train/space/space2057.jpg',
#  '../input/fingerdataset/dataset/train/space/space1128.jpg',
#  '../input/fingerdataset/dataset/train/space/space2058.jpg',
#  '../input/fingerdataset/dataset/train/space/space1126.jpg',
#  '../input/fingerdataset/dataset/train/space/space2610.jpg',
#  '../input/fingerdataset/dataset/train/space/space414.jpg',
#  '../input/fingerdataset/dataset/train/space/space756.jpg',
#  '../input/fingerdataset/dataset/train/space/space165.jpg',
#  '../input/fingerdataset/dataset/train/space/space755.jpg',
#  '../input/fingerdataset/dataset/train/space/space2611.jpg',
#  '../input/fingerdataset/dataset/train/space/space4.jpg',
#  '../input/fingerdataset/dataset/train/space/space3.jpg',
#  '../input/fingerdataset/dataset/train/space/space416.jpg',
#  '../input/fingerdataset/dataset/train/space/space2059.jpg',
#  '../input/fingerdataset/dataset/train/B/B634.jpg',
#  '../input/fingerdataset/dataset/train/B/B284.jpg',
#  '../input/fingerdataset/dataset/train/B/B1335.jpg',
#  '../input/fingerdataset/dataset/train/B/B2165.jpg',
#  '../input/fingerdataset/dataset/train/B/B1333.jpg',
#  '../input/fingerdataset/dataset/train/B/B492.jpg',
#  '../input/fingerdataset/dataset/train/B/B3.jpg',
#  '../input/fingerdataset/dataset/train/B/B1336.jpg',
#  '../input/fingerdataset/dataset/train/B/B732.jpg',
#  '../input/fingerdataset/dataset/train/B/B2166.jpg',
#  '../input/fingerdataset/dataset/train/B/B2168.jpg',
#  '../input/fingerdataset/dataset/train/B/B489.jpg',
#  '../input/fingerdataset/dataset/train/B/B1334.jpg',
#  '../input/fingerdataset/dataset/train/B/B1.jpg',
#  '../input/fingerdataset/dataset/train/B/B729.jpg',
#  '../input/fingerdataset/dataset/train/B/B491.jpg',
#  '../input/fingerdataset/dataset/train/B/B2.jpg',
#  '../input/fingerdataset/dataset/train/B/B636.jpg',
#  '../input/fingerdataset/dataset/train/B/B283.jpg',
#  '../input/fingerdataset/dataset/train/B/B730.jpg',
#  '../input/fingerdataset/dataset/train/B/B635.jpg',
#  '../input/fingerdataset/dataset/train/B/B281.jpg',
#  '../input/fingerdataset/dataset/train/B/B490.jpg',
#  '../input/fingerdataset/dataset/train/B/B633.jpg',
#  '../input/fingerdataset/dataset/train/B/B2167.jpg',
#  '../input/fingerdataset/dataset/train/B/B731.jpg',
#  '../input/fingerdataset/dataset/train/B/B282.jpg',
#  '../input/fingerdataset/dataset/train/B/B4.jpg',
#  '../input/fingerdataset/dataset/train/I/I4.jpg',
#  '../input/fingerdataset/dataset/train/I/I1601.jpg',
#  '../input/fingerdataset/dataset/train/I/I1603.jpg',
#  '../input/fingerdataset/dataset/train/I/I817.jpg',
#  '../input/fingerdataset/dataset/train/I/I1.jpg',
#  '../input/fingerdataset/dataset/train/I/I819.jpg',
#  '../input/fingerdataset/dataset/train/I/I1082.jpg',
#  '../input/fingerdataset/dataset/train/I/I2577.jpg',
#  '../input/fingerdataset/dataset/train/I/I2120.jpg',
#  '../input/fingerdataset/dataset/train/I/I2.jpg',
#  '../input/fingerdataset/dataset/train/I/I1604.jpg',
#  '../input/fingerdataset/dataset/train/I/I818.jpg',
#  '../input/fingerdataset/dataset/train/I/I318.jpg',
#  '../input/fingerdataset/dataset/train/I/I3.jpg',
#  '../input/fingerdataset/dataset/train/I/I2579.jpg',
#  '../input/fingerdataset/dataset/train/I/I319.jpg',
#  '../input/fingerdataset/dataset/train/I/I2578.jpg',
#  '../input/fingerdataset/dataset/train/I/I1602.jpg',
#  '../input/fingerdataset/dataset/train/I/I820.jpg',
#  '../input/fingerdataset/dataset/train/I/I1083.jpg',
#  '../input/fingerdataset/dataset/train/I/I2117.jpg',
#  '../input/fingerdataset/dataset/train/I/I1084.jpg',
#  '../input/fingerdataset/dataset/train/I/I2580.jpg',
#  '../input/fingerdataset/dataset/train/I/I317.jpg',
#  '../input/fingerdataset/dataset/train/I/I1081.jpg',
#  '../input/fingerdataset/dataset/train/I/I2119.jpg',
#  '../input/fingerdataset/dataset/train/I/I2118.jpg',
#  '../input/fingerdataset/dataset/train/I/I320.jpg',
#  '../input/fingerdataset/dataset/train/del/del1701.jpg',
#  '../input/fingerdataset/dataset/train/del/del1217.jpg',
#  '../input/fingerdataset/dataset/train/del/del1582.jpg',
#  '../input/fingerdataset/dataset/train/del/del3.jpg',
#  '../input/fingerdataset/dataset/train/del/del1837.jpg',
#  '../input/fingerdataset/dataset/train/del/del4.jpg',
#  '../input/fingerdataset/dataset/train/del/del2078.jpg',
#  '../input/fingerdataset/dataset/train/del/del1703.jpg',
#  '../input/fingerdataset/dataset/train/del/del1704.jpg',
#  '../input/fingerdataset/dataset/train/del/del1583.jpg',
#  '../input/fingerdataset/dataset/train/del/del1218.jpg',
#  '../input/fingerdataset/dataset/train/del/del1702.jpg',
#  '../input/fingerdataset/dataset/train/del/del1581.jpg',
#  '../input/fingerdataset/dataset/train/del/del1840.jpg',
#  '../input/fingerdataset/dataset/train/del/del1220.jpg',
#  '../input/fingerdataset/dataset/train/del/del552.jpg',
#  '../input/fingerdataset/dataset/train/del/del550.jpg',
#  '../input/fingerdataset/dataset/train/del/del2077.jpg',
#  '../input/fingerdataset/dataset/train/del/del549.jpg',
#  '../input/fingerdataset/dataset/train/del/del1838.jpg',
#  '../input/fingerdataset/dataset/train/del/del551.jpg',
#  '../input/fingerdataset/dataset/train/del/del1.jpg',
#  '../input/fingerdataset/dataset/train/del/del1584.jpg',
#  '../input/fingerdataset/dataset/train/del/del2079.jpg',
#  '../input/fingerdataset/dataset/train/del/del1839.jpg',
#  '../input/fingerdataset/dataset/train/del/del2.jpg',
#  '../input/fingerdataset/dataset/train/del/del2080.jpg',
#  '../input/fingerdataset/dataset/train/del/del1219.jpg',
#  '../input/fingerdataset/dataset/train/F/F1174.jpg',
#  '../input/fingerdataset/dataset/train/F/F368.jpg',
#  '../input/fingerdataset/dataset/train/F/F2562.jpg',
#  '../input/fingerdataset/dataset/train/F/F815.jpg',
#  '../input/fingerdataset/dataset/train/F/F2561.jpg',
#  '../input/fingerdataset/dataset/train/F/F1683.jpg',
#  '../input/fingerdataset/dataset/train/F/F366.jpg',
#  '../input/fingerdataset/dataset/train/F/F2029.jpg',
#  '../input/fingerdataset/dataset/train/F/F2031.jpg',
#  '../input/fingerdataset/dataset/train/F/F365.jpg',
#  '../input/fingerdataset/dataset/train/F/F4.jpg',
#  '../input/fingerdataset/dataset/train/F/F2564.jpg',
#  '../input/fingerdataset/dataset/train/F/F814.jpg',
#  '../input/fingerdataset/dataset/train/F/F813.jpg',
#  '../input/fingerdataset/dataset/train/F/F816.jpg',
#  '../input/fingerdataset/dataset/train/F/F1173.jpg',
#  '../input/fingerdataset/dataset/train/F/F1176.jpg',
#  '../input/fingerdataset/dataset/train/F/F2.jpg',
#  '../input/fingerdataset/dataset/train/F/F1175.jpg',
#  '../input/fingerdataset/dataset/train/F/F367.jpg',
#  '../input/fingerdataset/dataset/train/F/F1684.jpg',
#  '../input/fingerdataset/dataset/train/F/F1681.jpg',
#  '../input/fingerdataset/dataset/train/F/F3.jpg',
#  '../input/fingerdataset/dataset/train/F/F2563.jpg',
#  '../input/fingerdataset/dataset/train/F/F2030.jpg',
#  '../input/fingerdataset/dataset/train/F/F1682.jpg',
#  '../input/fingerdataset/dataset/train/F/F1.jpg',
#  '../input/fingerdataset/dataset/train/F/F2032.jpg',
#  '../input/fingerdataset/dataset/train/H/H2043.jpg',
#  '../input/fingerdataset/dataset/train/H/H2544.jpg',
#  '../input/fingerdataset/dataset/train/H/H1.jpg',
#  '../input/fingerdataset/dataset/train/H/H862.jpg',
#  '../input/fingerdataset/dataset/train/H/H518.jpg',
#  '../input/fingerdataset/dataset/train/H/H1005.jpg',
#  '../input/fingerdataset/dataset/train/H/H255.jpg',
#  '../input/fingerdataset/dataset/train/H/H2542.jpg',
#  '../input/fingerdataset/dataset/train/H/H1007.jpg',
#  '../input/fingerdataset/dataset/train/H/H519.jpg',
#  '../input/fingerdataset/dataset/train/H/H253.jpg',
#  '../input/fingerdataset/dataset/train/H/H2543.jpg',
#  '../input/fingerdataset/dataset/train/H/H2042.jpg',
#  '../input/fingerdataset/dataset/train/H/H1008.jpg',
#  '../input/fingerdataset/dataset/train/H/H861.jpg',
#  '../input/fingerdataset/dataset/train/H/H3.jpg',
#  '../input/fingerdataset/dataset/train/H/H2.jpg',
#  '../input/fingerdataset/dataset/train/H/H254.jpg',
#  '../input/fingerdataset/dataset/train/H/H863.jpg',
#  '../input/fingerdataset/dataset/train/H/H2041.jpg',
#  '../input/fingerdataset/dataset/train/H/H2541.jpg',
#  '../input/fingerdataset/dataset/train/H/H1006.jpg',
#  '../input/fingerdataset/dataset/train/H/H517.jpg',
#  '../input/fingerdataset/dataset/train/H/H520.jpg',
#  '../input/fingerdataset/dataset/train/H/H4.jpg',
#  '../input/fingerdataset/dataset/train/H/H256.jpg',
#  '../input/fingerdataset/dataset/train/H/H2044.jpg',
#  '../input/fingerdataset/dataset/train/H/H864.jpg',
#  '../input/fingerdataset/dataset/train/E/E4.jpg',
#  '../input/fingerdataset/dataset/train/E/E765.jpg',
#  '../input/fingerdataset/dataset/train/E/E2526.jpg',
#  '../input/fingerdataset/dataset/train/E/E829.jpg',
#  '../input/fingerdataset/dataset/train/E/E1361.jpg',
#  '../input/fingerdataset/dataset/train/E/E1363.jpg',
#  '../input/fingerdataset/dataset/train/E/E767.jpg',
#  '../input/fingerdataset/dataset/train/E/E832.jpg',
#  '../input/fingerdataset/dataset/train/E/E3.jpg',
#  '../input/fingerdataset/dataset/train/E/E2003.jpg',
#  '../input/fingerdataset/dataset/train/E/E1122.jpg',
#  '../input/fingerdataset/dataset/train/E/E2001.jpg',
#  '../input/fingerdataset/dataset/train/E/E1364.jpg',
#  '../input/fingerdataset/dataset/train/E/E2002.jpg',
#  '../input/fingerdataset/dataset/train/E/E2528.jpg',
#  '../input/fingerdataset/dataset/train/E/E831.jpg',
#  '../input/fingerdataset/dataset/train/E/E830.jpg',
#  '../input/fingerdataset/dataset/train/E/E766.jpg',
#  '../input/fingerdataset/dataset/train/E/E1362.jpg',
#  '../input/fingerdataset/dataset/train/E/E1123.jpg',
#  '../input/fingerdataset/dataset/train/E/E1124.jpg',
#  '../input/fingerdataset/dataset/train/E/E1121.jpg',
#  '../input/fingerdataset/dataset/train/E/E2527.jpg',
#  '../input/fingerdataset/dataset/train/E/E2004.jpg',
#  '../input/fingerdataset/dataset/train/E/E1.jpg',
#  '../input/fingerdataset/dataset/train/E/E2525.jpg',
#  '../input/fingerdataset/dataset/train/E/E2.jpg',
#  '../input/fingerdataset/dataset/train/E/E768.jpg',
#  '../input/fingerdataset/dataset/train/U/U2627.jpg',
#  '../input/fingerdataset/dataset/train/U/U1779.jpg',
#  '../input/fingerdataset/dataset/train/U/U2085.jpg',
#  '../input/fingerdataset/dataset/train/U/U2086.jpg',
#  '../input/fingerdataset/dataset/train/U/U2.jpg',
#  '../input/fingerdataset/dataset/train/U/U1.jpg',
#  '../input/fingerdataset/dataset/train/U/U2087.jpg',
#  '../input/fingerdataset/dataset/train/U/U1223.jpg',
#  '../input/fingerdataset/dataset/train/U/U3.jpg',
#  '../input/fingerdataset/dataset/train/U/U1780.jpg',
#  '../input/fingerdataset/dataset/train/U/U1224.jpg',
#  '../input/fingerdataset/dataset/train/U/U291.jpg',
#  '../input/fingerdataset/dataset/train/U/U1222.jpg',
#  '../input/fingerdataset/dataset/train/U/U289.jpg',
#  '../input/fingerdataset/dataset/train/U/U290.jpg',
#  '../input/fingerdataset/dataset/train/U/U4.jpg',
#  '../input/fingerdataset/dataset/train/U/U2088.jpg',
#  '../input/fingerdataset/dataset/train/U/U642.jpg',
#  '../input/fingerdataset/dataset/train/U/U1777.jpg',
#  '../input/fingerdataset/dataset/train/U/U1221.jpg',
#  '../input/fingerdataset/dataset/train/U/U641.jpg',
#  '../input/fingerdataset/dataset/train/U/U292.jpg',
#  '../input/fingerdataset/dataset/train/U/U2628.jpg',
#  '../input/fingerdataset/dataset/train/U/U643.jpg',
#  '../input/fingerdataset/dataset/train/U/U1778.jpg',
#  '../input/fingerdataset/dataset/train/U/U644.jpg',
#  '../input/fingerdataset/dataset/train/U/U2626.jpg',
#  '../input/fingerdataset/dataset/train/U/U2625.jpg',
#  '../input/fingerdataset/dataset/train/M/M476.jpg',
#  '../input/fingerdataset/dataset/train/M/M2009.jpg',
#  '../input/fingerdataset/dataset/train/M/M474.jpg',
#  '../input/fingerdataset/dataset/train/M/M3.jpg',
#  '../input/fingerdataset/dataset/train/M/M1104.jpg',
#  '../input/fingerdataset/dataset/train/M/M475.jpg',
#  '../input/fingerdataset/dataset/train/M/M1596.jpg',
#  '../input/fingerdataset/dataset/train/M/M1593.jpg',
#  '../input/fingerdataset/dataset/train/M/M790.jpg',
#  '../input/fingerdataset/dataset/train/M/M2603.jpg',
#  '../input/fingerdataset/dataset/train/M/M2602.jpg',
#  '../input/fingerdataset/dataset/train/M/M1103.jpg',
#  '../input/fingerdataset/dataset/train/M/M789.jpg',
#  '../input/fingerdataset/dataset/train/M/M2012.jpg',
#  '../input/fingerdataset/dataset/train/M/M2011.jpg',
#  '../input/fingerdataset/dataset/train/M/M1101.jpg',
#  '../input/fingerdataset/dataset/train/M/M2.jpg',
#  '../input/fingerdataset/dataset/train/M/M473.jpg',
#  '../input/fingerdataset/dataset/train/M/M791.jpg',
#  '../input/fingerdataset/dataset/train/M/M1595.jpg',
#  '../input/fingerdataset/dataset/train/M/M1594.jpg',
#  '../input/fingerdataset/dataset/train/M/M4.jpg',
#  '../input/fingerdataset/dataset/train/M/M792.jpg',
#  '../input/fingerdataset/dataset/train/M/M2010.jpg',
#  '../input/fingerdataset/dataset/train/M/M2604.jpg',
#  '../input/fingerdataset/dataset/train/M/M1102.jpg',
#  '../input/fingerdataset/dataset/train/M/M2601.jpg',
#  '../input/fingerdataset/dataset/train/M/M1.jpg',
#  '../input/fingerdataset/dataset/train/X/X1971.jpg',
#  '../input/fingerdataset/dataset/train/X/X770.jpg',
#  '../input/fingerdataset/dataset/train/X/X769.jpg',
#  '../input/fingerdataset/dataset/train/X/X1387.jpg',
#  '../input/fingerdataset/dataset/train/X/X521.jpg',
#  '../input/fingerdataset/dataset/train/X/X946.jpg',
#  '../input/fingerdataset/dataset/train/X/X771.jpg',
#  '../input/fingerdataset/dataset/train/X/X2220.jpg',
#  '../input/fingerdataset/dataset/train/X/X1972.jpg',
#  '../input/fingerdataset/dataset/train/X/X1970.jpg',
#  '../input/fingerdataset/dataset/train/X/X2217.jpg',
#  '../input/fingerdataset/dataset/train/X/X2218.jpg',
#  '../input/fingerdataset/dataset/train/X/X1385.jpg',
#  '../input/fingerdataset/dataset/train/X/X4.jpg',
#  '../input/fingerdataset/dataset/train/X/X2219.jpg',
#  '../input/fingerdataset/dataset/train/X/X947.jpg',
#  '../input/fingerdataset/dataset/train/X/X3.jpg',
#  '../input/fingerdataset/dataset/train/X/X772.jpg',
#  '../input/fingerdataset/dataset/train/X/X945.jpg',
#  '../input/fingerdataset/dataset/train/X/X524.jpg',
#  '../input/fingerdataset/dataset/train/X/X1969.jpg',
#  '../input/fingerdataset/dataset/train/X/X1.jpg',
#  '../input/fingerdataset/dataset/train/X/X948.jpg',
#  '../input/fingerdataset/dataset/train/X/X1388.jpg',
#  '../input/fingerdataset/dataset/train/X/X2.jpg',
#  '../input/fingerdataset/dataset/train/X/X1386.jpg',
#  '../input/fingerdataset/dataset/train/X/X523.jpg',
#  '../input/fingerdataset/dataset/train/X/X522.jpg',
#  '../input/fingerdataset/dataset/train/K/K2024.jpg',
#  '../input/fingerdataset/dataset/train/K/K657.jpg',
#  '../input/fingerdataset/dataset/train/K/K1188.jpg',
#  '../input/fingerdataset/dataset/train/K/K659.jpg',
#  '../input/fingerdataset/dataset/train/K/K1627.jpg',
#  '../input/fingerdataset/dataset/train/K/K2895.jpg',
#  '../input/fingerdataset/dataset/train/K/K1186.jpg',
#  '../input/fingerdataset/dataset/train/K/K660.jpg',
#  '../input/fingerdataset/dataset/train/K/K2.jpg',
#  '../input/fingerdataset/dataset/train/K/K1626.jpg',
#  '../input/fingerdataset/dataset/train/K/K1628.jpg',
#  '../input/fingerdataset/dataset/train/K/K4.jpg',
#  '../input/fingerdataset/dataset/train/K/K437.jpg',
#  '../input/fingerdataset/dataset/train/K/K1.jpg',
#  '../input/fingerdataset/dataset/train/K/K1185.jpg',
#  '../input/fingerdataset/dataset/train/K/K439.jpg',
#  '../input/fingerdataset/dataset/train/K/K2022.jpg',
#  '../input/fingerdataset/dataset/train/K/K2894.jpg',
#  '../input/fingerdataset/dataset/train/K/K1625.jpg',
#  '../input/fingerdataset/dataset/train/K/K2023.jpg',
#  '../input/fingerdataset/dataset/train/K/K3.jpg',
#  '../input/fingerdataset/dataset/train/K/K2893.jpg',
#  '../input/fingerdataset/dataset/train/K/K438.jpg',
#  '../input/fingerdataset/dataset/train/K/K2896.jpg',
#  '../input/fingerdataset/dataset/train/K/K658.jpg',
#  '../input/fingerdataset/dataset/train/K/K1187.jpg',
#  '../input/fingerdataset/dataset/train/K/K2021.jpg',
#  '../input/fingerdataset/dataset/train/K/K440.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q364.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q1011.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q2528.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q4.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q2.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q1032.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q251.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q362.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q1030.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q2111.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q361.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q252.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q105.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q2110.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q250.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q2112.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q2109.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q2526.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q1029.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q249.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q363.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q11.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q2525.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q1.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q3.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q1031.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q10.jpg',
#  '../input/fingerdataset/dataset/train/Q/Q2527.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y3.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y2096.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y437.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y1429.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y438.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y4.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y2094.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y583.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y830.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y1431.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y241.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y2093.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y440.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y1.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y2.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y1432.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y243.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y831.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y582.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y829.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y1430.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y242.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y584.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y439.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y581.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y2095.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y244.jpg',
#  '../input/fingerdataset/dataset/train/Y/Y832.jpg',
#  '../input/fingerdataset/dataset/train/S/S1365.jpg',
#  '../input/fingerdataset/dataset/train/S/S2011.jpg',
#  '../input/fingerdataset/dataset/train/S/S761.jpg',
#  '../input/fingerdataset/dataset/train/S/S462.jpg',
#  '../input/fingerdataset/dataset/train/S/S2.jpg',
#  '../input/fingerdataset/dataset/train/S/S2567.jpg',
#  '../input/fingerdataset/dataset/train/S/S461.jpg',
#  '../input/fingerdataset/dataset/train/S/S464.jpg',
#  '../input/fingerdataset/dataset/train/S/S1367.jpg',
#  '../input/fingerdataset/dataset/train/S/S2009.jpg',
#  '../input/fingerdataset/dataset/train/S/S935.jpg',
#  '../input/fingerdataset/dataset/train/S/S2010.jpg',
#  '../input/fingerdataset/dataset/train/S/S2565.jpg',
#  '../input/fingerdataset/dataset/train/S/S1366.jpg',
#  '../input/fingerdataset/dataset/train/S/S2566.jpg',
#  '../input/fingerdataset/dataset/train/S/S763.jpg',
#  '../input/fingerdataset/dataset/train/S/S2012.jpg',
#  '../input/fingerdataset/dataset/train/S/S764.jpg',
#  '../input/fingerdataset/dataset/train/S/S463.jpg',
#  '../input/fingerdataset/dataset/train/S/S762.jpg',
#  '../input/fingerdataset/dataset/train/S/S2568.jpg',
#  '../input/fingerdataset/dataset/train/S/S1.jpg',
#  '../input/fingerdataset/dataset/train/S/S934.jpg',
#  '../input/fingerdataset/dataset/train/S/S3.jpg',
#  '../input/fingerdataset/dataset/train/S/S4.jpg',
#  '../input/fingerdataset/dataset/train/S/S1368.jpg',
#  '../input/fingerdataset/dataset/train/S/S933.jpg',
#  '../input/fingerdataset/dataset/train/S/S936.jpg',
#  '../input/fingerdataset/dataset/train/G/G781.jpg',
#  '../input/fingerdataset/dataset/train/G/G293.jpg',
#  '../input/fingerdataset/dataset/train/G/G782.jpg',
#  '../input/fingerdataset/dataset/train/G/G3.jpg',
#  '../input/fingerdataset/dataset/train/G/G296.jpg',
#  '../input/fingerdataset/dataset/train/G/G1234.jpg',
#  '../input/fingerdataset/dataset/train/G/G431.jpg',
#  '../input/fingerdataset/dataset/train/G/G2.jpg',
#  '../input/fingerdataset/dataset/train/G/G1681.jpg',
#  '../input/fingerdataset/dataset/train/G/G2262.jpg',
#  '../input/fingerdataset/dataset/train/G/G1683.jpg',
#  '../input/fingerdataset/dataset/train/G/G295.jpg',
#  '../input/fingerdataset/dataset/train/G/G784.jpg',
#  '../input/fingerdataset/dataset/train/G/G1235.jpg',
#  '../input/fingerdataset/dataset/train/G/G1684.jpg',
#  '../input/fingerdataset/dataset/train/G/G4.jpg',
#  '../input/fingerdataset/dataset/train/G/G1682.jpg',
#  '../input/fingerdataset/dataset/train/G/G1233.jpg',
#  '../input/fingerdataset/dataset/train/G/G2261.jpg',
#  '../input/fingerdataset/dataset/train/G/G429.jpg',
#  '../input/fingerdataset/dataset/train/G/G2263.jpg',
#  '../input/fingerdataset/dataset/train/G/G294.jpg',
#  '../input/fingerdataset/dataset/train/G/G1236.jpg',
#  '../input/fingerdataset/dataset/train/G/G430.jpg',
#  '../input/fingerdataset/dataset/train/G/G2264.jpg',
#  '../input/fingerdataset/dataset/train/G/G1.jpg',
#  '../input/fingerdataset/dataset/train/G/G783.jpg',
#  '../input/fingerdataset/dataset/train/G/G432.jpg',
#  '../input/fingerdataset/dataset/train/A/A582.jpg',
#  '../input/fingerdataset/dataset/train/A/A1.jpg',
#  '../input/fingerdataset/dataset/train/A/A1014.jpg',
#  '../input/fingerdataset/dataset/train/A/A1015.jpg',
#  '../input/fingerdataset/dataset/train/A/A3.jpg',
#  '../input/fingerdataset/dataset/train/A/A742.jpg',
#  '../input/fingerdataset/dataset/train/A/A2.jpg',
#  '../input/fingerdataset/dataset/train/A/A877.jpg',
#  '../input/fingerdataset/dataset/train/A/A2031.jpg',
#  '../input/fingerdataset/dataset/train/A/A1337.jpg',
#  '../input/fingerdataset/dataset/train/A/A1013.jpg',
#  '../input/fingerdataset/dataset/train/A/A1338.jpg',
#  '../input/fingerdataset/dataset/train/A/A744.jpg',
#  '../input/fingerdataset/dataset/train/A/A879.jpg',
#  '../input/fingerdataset/dataset/train/A/A584.jpg',
#  '../input/fingerdataset/dataset/train/A/A2029.jpg',
#  '../input/fingerdataset/dataset/train/A/A2032.jpg',
#  '../input/fingerdataset/dataset/train/A/A1339.jpg',
#  '../input/fingerdataset/dataset/train/A/A1340.jpg',
#  '../input/fingerdataset/dataset/train/A/A878.jpg',
#  '../input/fingerdataset/dataset/train/A/A741.jpg',
#  '../input/fingerdataset/dataset/train/A/A583.jpg',
#  '../input/fingerdataset/dataset/train/A/A581.jpg',
#  '../input/fingerdataset/dataset/train/A/A743.jpg',
#  '../input/fingerdataset/dataset/train/A/A880.jpg',
#  '../input/fingerdataset/dataset/train/A/A2030.jpg',
#  '../input/fingerdataset/dataset/train/A/A4.jpg',
#  '../input/fingerdataset/dataset/train/A/A1016.jpg',
#  '../input/fingerdataset/dataset/train/O/O1554.jpg',
#  '../input/fingerdataset/dataset/train/O/O2055.jpg',
#  '../input/fingerdataset/dataset/train/O/O1556.jpg',
#  '../input/fingerdataset/dataset/train/O/O1090.jpg',
#  '../input/fingerdataset/dataset/train/O/O2683.jpg',
#  '../input/fingerdataset/dataset/train/O/O2681.jpg',
#  '../input/fingerdataset/dataset/train/O/O1.jpg',
#  '../input/fingerdataset/dataset/train/O/O3.jpg',
#  '../input/fingerdataset/dataset/train/O/O668.jpg',
#  '../input/fingerdataset/dataset/train/O/O1091.jpg',
#  '../input/fingerdataset/dataset/train/O/O666.jpg',
#  '../input/fingerdataset/dataset/train/O/O921.jpg',
#  '../input/fingerdataset/dataset/train/O/O2056.jpg',
#  '../input/fingerdataset/dataset/train/O/O924.jpg',
#  '../input/fingerdataset/dataset/train/O/O1092.jpg',
#  '../input/fingerdataset/dataset/train/O/O2053.jpg',
#  '../input/fingerdataset/dataset/train/O/O2682.jpg',
#  '../input/fingerdataset/dataset/train/O/O4.jpg',
#  '../input/fingerdataset/dataset/train/O/O922.jpg',
#  '../input/fingerdataset/dataset/train/O/O923.jpg',
#  '../input/fingerdataset/dataset/train/O/O2.jpg',
#  '../input/fingerdataset/dataset/train/O/O1089.jpg',
#  '../input/fingerdataset/dataset/train/O/O2684.jpg',
#  '../input/fingerdataset/dataset/train/O/O667.jpg',
#  '../input/fingerdataset/dataset/train/O/O2054.jpg',
#  '../input/fingerdataset/dataset/train/O/O1555.jpg',
#  '../input/fingerdataset/dataset/train/O/O1553.jpg',
#  '../input/fingerdataset/dataset/train/O/O665.jpg',
#  '../input/fingerdataset/dataset/train/T/T1257.jpg',
#  '../input/fingerdataset/dataset/train/T/T2511.jpg',
#  '../input/fingerdataset/dataset/train/T/T2037.jpg',
#  '../input/fingerdataset/dataset/train/T/T610.jpg',
#  '../input/fingerdataset/dataset/train/T/T2509.jpg',
#  '../input/fingerdataset/dataset/train/T/T2038.jpg',
#  '../input/fingerdataset/dataset/train/T/T4.jpg',
#  '../input/fingerdataset/dataset/train/T/T980.jpg',
#  '../input/fingerdataset/dataset/train/T/T1406.jpg',
#  '../input/fingerdataset/dataset/train/T/T612.jpg',
#  '../input/fingerdataset/dataset/train/T/T1259.jpg',
#  '../input/fingerdataset/dataset/train/T/T1408.jpg',
#  '../input/fingerdataset/dataset/train/T/T977.jpg',
#  '../input/fingerdataset/dataset/train/T/T611.jpg',
#  '../input/fingerdataset/dataset/train/T/T609.jpg',
#  '../input/fingerdataset/dataset/train/T/T978.jpg',
#  '../input/fingerdataset/dataset/train/T/T2039.jpg',
#  '../input/fingerdataset/dataset/train/T/T2040.jpg',
#  '../input/fingerdataset/dataset/train/T/T2512.jpg',
#  '../input/fingerdataset/dataset/train/T/T3.jpg',
#  '../input/fingerdataset/dataset/train/T/T979.jpg',
#  '../input/fingerdataset/dataset/train/T/T2510.jpg',
#  '../input/fingerdataset/dataset/train/T/T1260.jpg',
#  '../input/fingerdataset/dataset/train/T/T1.jpg',
#  '../input/fingerdataset/dataset/train/T/T2.jpg',
#  '../input/fingerdataset/dataset/train/T/T1407.jpg',
#  '../input/fingerdataset/dataset/train/T/T1258.jpg',
#  '../input/fingerdataset/dataset/train/T/T1405.jpg',
#  '../input/fingerdataset/dataset/train/V/V2007.jpg',
#  '../input/fingerdataset/dataset/train/V/V1080.jpg',
#  '../input/fingerdataset/dataset/train/V/V741.jpg',
#  '../input/fingerdataset/dataset/train/V/V1078.jpg',
#  '../input/fingerdataset/dataset/train/V/V2.jpg',
#  '../input/fingerdataset/dataset/train/V/V230.jpg',
#  '../input/fingerdataset/dataset/train/V/V2513.jpg',
#  '../input/fingerdataset/dataset/train/V/V232.jpg',
#  '../input/fingerdataset/dataset/train/V/V4.jpg',
#  '../input/fingerdataset/dataset/train/V/V229.jpg',
#  '../input/fingerdataset/dataset/train/V/V2516.jpg',
#  '../input/fingerdataset/dataset/train/V/V1079.jpg',
#  '../input/fingerdataset/dataset/train/V/V2514.jpg',
#  '../input/fingerdataset/dataset/train/V/V744.jpg',
#  '../input/fingerdataset/dataset/train/V/V1.jpg',
#  '../input/fingerdataset/dataset/train/V/V3.jpg',
#  '../input/fingerdataset/dataset/train/V/V742.jpg',
#  '../input/fingerdataset/dataset/train/V/V2008.jpg',
#  '../input/fingerdataset/dataset/train/V/V231.jpg',
#  '../input/fingerdataset/dataset/train/V/V2515.jpg',
#  '../input/fingerdataset/dataset/train/V/V1077.jpg',
#  '../input/fingerdataset/dataset/train/V/V464.jpg',
#  '../input/fingerdataset/dataset/train/V/V463.jpg',
#  '../input/fingerdataset/dataset/train/V/V743.jpg',
#  '../input/fingerdataset/dataset/train/V/V461.jpg',
#  '../input/fingerdataset/dataset/train/V/V462.jpg',
#  '../input/fingerdataset/dataset/train/V/V2005.jpg',
#  '../input/fingerdataset/dataset/train/V/V2006.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z2.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z3.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z2770.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z2234.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z2235.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z112.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z346.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z2236.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z2233.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z2771.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z1424.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z891.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z4.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z1.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z892.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z1421.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z345.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z109.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z2769.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z347.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z110.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z111.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z889.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z1423.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z348.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z890.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z1422.jpg',
#  '../input/fingerdataset/dataset/train/Z/Z2772.jpg',
#  '../input/fingerdataset/dataset/train/C/C2074.jpg',
#  '../input/fingerdataset/dataset/train/C/C1976.jpg',
#  '../input/fingerdataset/dataset/train/C/C606.jpg',
#  '../input/fingerdataset/dataset/train/C/C4.jpg',
#  '../input/fingerdataset/dataset/train/C/C1377.jpg',
#  '../input/fingerdataset/dataset/train/C/C3.jpg',
#  '../input/fingerdataset/dataset/train/C/C1.jpg',
#  '../input/fingerdataset/dataset/train/C/C1066.jpg',
#  '../input/fingerdataset/dataset/train/C/C1068.jpg',
#  '../input/fingerdataset/dataset/train/C/C2576.jpg',
#  '../input/fingerdataset/dataset/train/C/C605.jpg',
#  '../input/fingerdataset/dataset/train/C/C2075.jpg',
#  '../input/fingerdataset/dataset/train/C/C2073.jpg',
#  '../input/fingerdataset/dataset/train/C/C1974.jpg',
#  '../input/fingerdataset/dataset/train/C/C2076.jpg',
#  '../input/fingerdataset/dataset/train/C/C1378.jpg',
#  '../input/fingerdataset/dataset/train/C/C2574.jpg',
#  '../input/fingerdataset/dataset/train/C/C2.jpg',
#  '../input/fingerdataset/dataset/train/C/C1973.jpg',
#  '../input/fingerdataset/dataset/train/C/C1379.jpg',
#  '../input/fingerdataset/dataset/train/C/C1067.jpg',
#  '../input/fingerdataset/dataset/train/C/C1975.jpg',
#  '../input/fingerdataset/dataset/train/C/C1065.jpg',
#  '../input/fingerdataset/dataset/train/C/C2573.jpg',
#  '../input/fingerdataset/dataset/train/C/C1380.jpg',
#  '../input/fingerdataset/dataset/train/C/C607.jpg',
#  '../input/fingerdataset/dataset/train/C/C2575.jpg',
#  '../input/fingerdataset/dataset/train/C/C608.jpg',
#  '../input/fingerdataset/dataset/train/P/P2680.jpg',
#  '../input/fingerdataset/dataset/train/P/P1.jpg',
#  '../input/fingerdataset/dataset/train/P/P2678.jpg',
#  '../input/fingerdataset/dataset/train/P/P2.jpg',
#  '../input/fingerdataset/dataset/train/P/P329.jpg',
#  '../input/fingerdataset/dataset/train/P/P1327.jpg',
#  '../input/fingerdataset/dataset/train/P/P1002.jpg',
#  '../input/fingerdataset/dataset/train/P/P332.jpg',
#  '../input/fingerdataset/dataset/train/P/P2677.jpg',
#  '../input/fingerdataset/dataset/train/P/P330.jpg',
#  '../input/fingerdataset/dataset/train/P/P3.jpg',
#  '../input/fingerdataset/dataset/train/P/P2097.jpg',
#  '../input/fingerdataset/dataset/train/P/P603.jpg',
#  '../input/fingerdataset/dataset/train/P/P331.jpg',
#  '../input/fingerdataset/dataset/train/P/P1001.jpg',
#  '../input/fingerdataset/dataset/train/P/P601.jpg',
#  '../input/fingerdataset/dataset/train/P/P1326.jpg',
#  '../input/fingerdataset/dataset/train/P/P2098.jpg',
#  '../input/fingerdataset/dataset/train/P/P1328.jpg',
#  '../input/fingerdataset/dataset/train/P/P604.jpg',
#  '../input/fingerdataset/dataset/train/P/P1325.jpg',
#  '../input/fingerdataset/dataset/train/P/P2100.jpg',
#  '../input/fingerdataset/dataset/train/P/P1004.jpg',
#  '../input/fingerdataset/dataset/train/P/P2679.jpg',
#  '../input/fingerdataset/dataset/train/P/P2099.jpg',
#  '../input/fingerdataset/dataset/train/P/P1003.jpg',
#  '../input/fingerdataset/dataset/train/P/P4.jpg',
#  '../input/fingerdataset/dataset/train/P/P602.jpg',
#  '../input/fingerdataset/dataset/train/L/L2111.jpg',
#  '../input/fingerdataset/dataset/train/L/L1496.jpg',
#  '../input/fingerdataset/dataset/train/L/L549.jpg',
#  '../input/fingerdataset/dataset/train/L/L2932.jpg',
#  '../input/fingerdataset/dataset/train/L/L550.jpg',
#  '../input/fingerdataset/dataset/train/L/L2930.jpg',
#  '../input/fingerdataset/dataset/train/L/L551.jpg',
#  '../input/fingerdataset/dataset/train/L/L800.jpg',
#  '../input/fingerdataset/dataset/train/L/L1494.jpg',
#  '../input/fingerdataset/dataset/train/L/L552.jpg',
#  '../input/fingerdataset/dataset/train/L/L3.jpg',
#  '../input/fingerdataset/dataset/train/L/L1.jpg',
#  '../input/fingerdataset/dataset/train/L/L4.jpg',
#  '../input/fingerdataset/dataset/train/L/L2.jpg',
#  '../input/fingerdataset/dataset/train/L/L1493.jpg',
#  '../input/fingerdataset/dataset/train/L/L2112.jpg',
#  '../input/fingerdataset/dataset/train/L/L2929.jpg',
#  '../input/fingerdataset/dataset/train/L/L1495.jpg',
#  '../input/fingerdataset/dataset/train/L/L798.jpg',
#  '../input/fingerdataset/dataset/train/L/L1005.jpg',
#  '../input/fingerdataset/dataset/train/L/L797.jpg',
#  '../input/fingerdataset/dataset/train/L/L1007.jpg',
#  '../input/fingerdataset/dataset/train/L/L799.jpg',
#  '../input/fingerdataset/dataset/train/L/L1006.jpg',
#  '../input/fingerdataset/dataset/train/L/L1008.jpg',
#  '../input/fingerdataset/dataset/train/L/L2110.jpg',
#  '../input/fingerdataset/dataset/train/L/L2931.jpg',
#  '../input/fingerdataset/dataset/train/L/L2109.jpg',
#  '../input/fingerdataset/dataset/train/W/W184.jpg',
#  '../input/fingerdataset/dataset/train/W/W1377.jpg',
#  '../input/fingerdataset/dataset/train/W/W181.jpg',
#  '../input/fingerdataset/dataset/train/W/W2042.jpg',
#  '../input/fingerdataset/dataset/train/W/W2809.jpg',
#  '../input/fingerdataset/dataset/train/W/W2.jpg',
#  '../input/fingerdataset/dataset/train/W/W150.jpg',
#  '../input/fingerdataset/dataset/train/W/W1380.jpg',
#  '../input/fingerdataset/dataset/train/W/W2811.jpg',
#  '../input/fingerdataset/dataset/train/W/W182.jpg',
#  '../input/fingerdataset/dataset/train/W/W1378.jpg',
#  '../input/fingerdataset/dataset/train/W/W151.jpg',
#  '../input/fingerdataset/dataset/train/W/W152.jpg',
#  '../input/fingerdataset/dataset/train/W/W1379.jpg',
#  '../input/fingerdataset/dataset/train/W/W290.jpg',
#  '../input/fingerdataset/dataset/train/W/W289.jpg',
#  '../input/fingerdataset/dataset/train/W/W1.jpg',
#  '../input/fingerdataset/dataset/train/W/W3.jpg',
#  '../input/fingerdataset/dataset/train/W/W2812.jpg',
#  '../input/fingerdataset/dataset/train/W/W149.jpg',
#  '../input/fingerdataset/dataset/train/W/W2044.jpg',
#  '../input/fingerdataset/dataset/train/W/W2041.jpg',
#  '../input/fingerdataset/dataset/train/W/W183.jpg',
#  '../input/fingerdataset/dataset/train/W/W291.jpg',
#  '../input/fingerdataset/dataset/train/W/W2043.jpg',
#  '../input/fingerdataset/dataset/train/W/W2810.jpg',
#  '../input/fingerdataset/dataset/train/W/W4.jpg',
#  '../input/fingerdataset/dataset/train/W/W292.jpg',
#  '../input/fingerdataset/dataset/train/D/D2426.jpg',
#  '../input/fingerdataset/dataset/train/D/D1322.jpg',
#  '../input/fingerdataset/dataset/train/D/D1041.jpg',
#  '../input/fingerdataset/dataset/train/D/D1043.jpg',
#  '../input/fingerdataset/dataset/train/D/D2.jpg',
#  '../input/fingerdataset/dataset/train/D/D1321.jpg',
#  '../input/fingerdataset/dataset/train/D/D846.jpg',
#  '../input/fingerdataset/dataset/train/D/D2145.jpg',
#  '../input/fingerdataset/dataset/train/D/D2427.jpg',
#  '../input/fingerdataset/dataset/train/D/D847.jpg',
#  '../input/fingerdataset/dataset/train/D/D1666.jpg',
#  '../input/fingerdataset/dataset/train/D/D1665.jpg',
#  '../input/fingerdataset/dataset/train/D/D1044.jpg',
#  '../input/fingerdataset/dataset/train/D/D1.jpg',
#  '../input/fingerdataset/dataset/train/D/D2428.jpg',
#  '../input/fingerdataset/dataset/train/D/D4.jpg',
#  '../input/fingerdataset/dataset/train/D/D2146.jpg',
#  '../input/fingerdataset/dataset/train/D/D1323.jpg',
#  '../input/fingerdataset/dataset/train/D/D1668.jpg',
#  '../input/fingerdataset/dataset/train/D/D1667.jpg',
#  '../input/fingerdataset/dataset/train/D/D2147.jpg',
#  '../input/fingerdataset/dataset/train/D/D845.jpg',
#  '../input/fingerdataset/dataset/train/D/D3.jpg',
#  '../input/fingerdataset/dataset/train/D/D2148.jpg',
#  '../input/fingerdataset/dataset/train/D/D1042.jpg',
#  '../input/fingerdataset/dataset/train/D/D848.jpg',
#  '../input/fingerdataset/dataset/train/D/D2425.jpg',
#  '../input/fingerdataset/dataset/train/D/D1324.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing1306.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing429.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing737.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing948.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing432.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing3.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing946.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing1750.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing2155.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing430.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing1751.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing2154.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing739.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing1307.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing1308.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing1.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing2.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing738.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing945.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing431.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing1305.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing2156.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing1749.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing4.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing740.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing1752.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing947.jpg',
#  '../input/fingerdataset/dataset/train/nothing/nothing2153.jpg',
#  '../input/fingerdataset/dataset/train/J/J2089.jpg',
#  '../input/fingerdataset/dataset/train/J/J1291.jpg',
#  '../input/fingerdataset/dataset/train/J/J501.jpg',
#  '../input/fingerdataset/dataset/train/J/J4.jpg',
#  '../input/fingerdataset/dataset/train/J/J2.jpg',
#  '../input/fingerdataset/dataset/train/J/J2546.jpg',
#  '../input/fingerdataset/dataset/train/J/J2092.jpg',
#  '../input/fingerdataset/dataset/train/J/J1039.jpg',
#  '../input/fingerdataset/dataset/train/J/J2548.jpg',
#  '../input/fingerdataset/dataset/train/J/J2091.jpg',
#  '../input/fingerdataset/dataset/train/J/J1292.jpg',
#  '../input/fingerdataset/dataset/train/J/J1289.jpg',
#  '../input/fingerdataset/dataset/train/J/J1290.jpg',
#  '../input/fingerdataset/dataset/train/J/J1038.jpg',
#  '../input/fingerdataset/dataset/train/J/J781.jpg',
#  '../input/fingerdataset/dataset/train/J/J782.jpg',
#  '../input/fingerdataset/dataset/train/J/J502.jpg',
#  '../input/fingerdataset/dataset/train/J/J2545.jpg',
#  '../input/fingerdataset/dataset/train/J/J504.jpg',
#  '../input/fingerdataset/dataset/train/J/J1040.jpg',
#  '../input/fingerdataset/dataset/train/J/J2547.jpg',
#  '../input/fingerdataset/dataset/train/J/J783.jpg',
#  '../input/fingerdataset/dataset/train/J/J3.jpg',
#  '../input/fingerdataset/dataset/train/J/J784.jpg',
#  '../input/fingerdataset/dataset/train/J/J1037.jpg',
#  '../input/fingerdataset/dataset/train/J/J2090.jpg',
#  '../input/fingerdataset/dataset/train/J/J1.jpg',
#  '../input/fingerdataset/dataset/train/J/J503.jpg']

# %%
#sampler
train_sampler = SubsetRandomSampler(np.arange(len(train)))
test_sampler = SubsetRandomSampler(np.arange(len(test)))

# %%
#train and test loader using sampler
train_loader = DataLoader(train, 32, sampler=train_sampler)
test_loader = DataLoader(test, 32, sampler=test_sampler)
#we create data loader with 32-32

# %%
for x, y in train_loader:
    print(x.shape)
    print(y.shape)
#To check the shape of the train loader
#Each mini-batch has 32 images and 3 color channels and dimension 224 * 224.
# Out:
# torch.Size([32, 3, 224, 224])
# torch.Size([32])
# torch.Size([32, 3, 224, 224])
# torch.Size([32])
# torch.Size([32, 3, 224, 224])
# torch.Size([32])
# torch.Size([32, 3, 224, 224])
# torch.Size([32])
# torch.Size([32, 3, 224, 224])
# torch.Size([32])
# torch.Size([32, 3, 224, 224])
# torch.Size([32])
# torch.Size([32, 3, 224, 224])
# torch.Size([32])
# torch.Size([32, 3, 224, 224])
# torch.Size([32])
# torch.Size([32, 3, 224, 224])
# torch.Size([32])
# torch.Size([32, 3, 224, 224])
# torch.Size([32])
# torch.Size([32, 3, 224, 224])
# torch.Size([32])
# torch.Size([32, 3, 224, 224])
# torch.Size([32])
# torch.Size([32, 3, 224, 224])
# torch.Size([32])
# torch.Size([32, 3, 224, 224])
# torch.Size([32])
# torch.Size([32, 3, 224, 224])
# torch.Size([32])
# torch.Size([32, 3, 224, 224])
# torch.Size([32])
# torch.Size([32, 3, 224, 224])
# torch.Size([32])
# torch.Size([32, 3, 224, 224])
# torch.Size([32])
# torch.Size([32, 3, 224, 224])
# torch.Size([32])
# torch.Size([32, 3, 224, 224])
# torch.Size([32])
# torch.Size([32, 3, 224, 224])
# torch.Size([32])
# torch.Size([32, 3, 224, 224])
# torch.Size([32])
# torch.Size([32, 3, 224, 224])
# torch.Size([32])
# torch.Size([32, 3, 224, 224])
# torch.Size([32])
# torch.Size([32, 3, 224, 224])
# torch.Size([32])
# torch.Size([12, 3, 224, 224])
# torch.Size([12])

# %% [markdown]
# # **Alexnet**

# %%
class AlexNet(nn.Module):
    def __init__(self, num_classes: int = 1000) -> None:
        super(AlexNet, self).__init__()
        
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.avgpool = nn.AdaptiveAvgPool2d((6, 6))
        
        self.classifier = nn.Sequential(
            nn.Dropout(),
            nn.Linear(256 * 6 * 6, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Linear(4096, num_classes),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# %%
model = AlexNet(29)
#Initially there are 1000 classes here, 
#but since I have 29 classes here, I will define them in parameters.

# %%
#using adam optimizer
criterion = nn.CrossEntropyLoss()
optimizer = Adam(model.parameters(), lr=0.0001)

# %%
#print minibatch of the train data
print(len(train_loader.dataset))
print(len(train_loader))
#to check total data and mini-batch
# Out:
# 812
# 26

# %%
epochs = 20

for e in range(epochs):
    running_loss = 0.0
    
    for i, (imgs, labels) in enumerate(train_loader):
        outputs = model(imgs)
        loss = criterion(outputs, labels)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        if i % 13 == 12:
            print('[Epoch %d, Step %5d] loss: %.3f' %
                  (e + 1, i + 1, running_loss / 13))
            running_loss = 0.0
#I want the result after 13 mini-batch so I have set 13 in condition.
# Out:
# [Epoch 1, Step    13] loss: 4.185
# [Epoch 1, Step    26] loss: 3.405
# [Epoch 2, Step    13] loss: 3.363
# [Epoch 2, Step    26] loss: 3.352
# [Epoch 3, Step    13] loss: 3.300
# [Epoch 3, Step    26] loss: 3.281
# [Epoch 4, Step    13] loss: 3.110
# [Epoch 4, Step    26] loss: 2.895
# [Epoch 5, Step    13] loss: 2.712
# [Epoch 5, Step    26] loss: 2.484
# [Epoch 6, Step    13] loss: 2.284
# [Epoch 6, Step    26] loss: 1.924
# [Epoch 7, Step    13] loss: 1.689
# [Epoch 7, Step    26] loss: 1.486
# [Epoch 8, Step    13] loss: 1.268
# [Epoch 8, Step    26] loss: 1.262
# [Epoch 9, Step    13] loss: 1.052
# [Epoch 9, Step    26] loss: 1.008
# [Epoch 10, Step    13] loss: 0.927
# [Epoch 10, Step    26] loss: 0.809
# [Epoch 11, Step    13] loss: 0.683
# [Epoch 11, Step    26] loss: 0.609
# [Epoch 12, Step    13] loss: 0.538
# [Epoch 12, Step    26] loss: 0.417
# [Epoch 13, Step    13] loss: 0.334
# [Epoch 13, Step    26] loss: 0.414
# [Epoch 14, Step    13] loss: 0.254
# [Epoch 14, Step    26] loss: 0.296
# [Epoch 15, Step    13] loss: 0.286
# [Epoch 15, Step    26] loss: 0.266
# [Epoch 16, Step    13] loss: 0.265
# [Epoch 16, Step    26] loss: 0.259
# [Epoch 17, Step    13] loss: 0.255
# [Epoch 17, Step    26] loss: 0.190
# [Epoch 18, Step    13] loss: 0.249
# [Epoch 18, Step    26] loss: 0.271
# [Epoch 19, Step    13] loss: 0.181
# [Epoch 19, Step    26] loss: 0.149
# [Epoch 20, Step    13] loss: 0.131
# [Epoch 20, Step    26] loss: 0.118

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \nAccuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
test(test_loader, model, nn.CrossEntropyLoss())
# Out:
# Test Error:
# Accuracy: 50.2%, Avg loss: 3.152189

# %%
#each class wise accuracy
class_correct = list(0. for i in range(29))
class_total = list(0. for i in range(29))

with torch.no_grad():
    for data in test_loader:
        images, labels = data
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(len(labels)):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(29):
    print('Accuracy of %5s : %2d %%' % (
        ASLDatasetTest.int_to_char[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of     A : 42 %
# Accuracy of     B : 71 %
# Accuracy of     C : 57 %
# Accuracy of     D : 57 %
# Accuracy of     E : 42 %
# Accuracy of     F : 71 %
# Accuracy of     G : 57 %
# Accuracy of     H : 42 %
# Accuracy of     I : 28 %
# Accuracy of     J : 28 %
# Accuracy of     K : 71 %
# Accuracy of     L : 42 %
# Accuracy of     M : 57 %
# Accuracy of     N : 57 %
# Accuracy of     O : 57 %
# Accuracy of     P : 14 %
# Accuracy of     Q : 42 %
# Accuracy of     R : 42 %
# Accuracy of     S : 42 %
# Accuracy of     T : 42 %
# Accuracy of     U : 14 %
# Accuracy of     V : 42 %
# Accuracy of     W : 42 %
# Accuracy of     X : 42 %
# Accuracy of     Y : 28 %
# Accuracy of     Z : 42 %
# Accuracy of   del : 57 %
# Accuracy of nothing : 71 %
# Accuracy of space : 57 %

# %% [markdown]
# # **Pre-trained AlexNet**

# %%
from torchvision import models

# %% [markdown]
# **Issue on kaggle anyone trying to download the model will fail if the internet option is off at the bottom right.**

# %%
model = models.alexnet(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-4df8aa71.pth
#   0%|          | 0.00/233M [00:00<?, ?B/s]

# %%
for param in model.parameters():
    param.requires_grad = False

# %%
print(model)
#To check the model
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
new_clf = nn.Sequential(
    nn.Dropout(p=0.5, inplace=False),
    nn.Linear(in_features=9216, out_features=4096, bias=True),
    nn.ReLU(inplace=True),
    nn.Dropout(p=0.5, inplace=False),
    nn.Linear(in_features=4096, out_features=4096, bias=True),
    nn.ReLU(inplace=True),
    nn.Linear(in_features=4096, out_features=1000, bias=True),
    nn.ReLU(inplace=True),
    nn.Linear(in_features=1000, out_features=29, bias=True),
)
#Initially they define 1000 feature/class but i set the manually features 29

# %%
model.classifier = new_clf
#I have replaced the new classifier I created in the previous classifier.

# %%
criterion = nn.CrossEntropyLoss()
optimizer = Adam(model.parameters(), lr=0.0001)

# %%
epochs = 20

for e in range(epochs):
    running_loss = 0.0
    for i, (imgs, labels) in enumerate(train_loader):
        outputs = model(imgs)
        loss = criterion(outputs, labels)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        if i % 13 == 12:
            print('[Epoch %d, Step %5d] loss: %.3f' %
                  (e + 1, i + 1, running_loss / 13))
            running_loss = 0.0
# Out:
# [Epoch 1, Step    13] loss: 29.168
# [Epoch 1, Step    26] loss: 11.136
# [Epoch 2, Step    13] loss: 5.362
# [Epoch 2, Step    26] loss: 3.957
# [Epoch 3, Step    13] loss: 3.405
# [Epoch 3, Step    26] loss: 3.092
# [Epoch 4, Step    13] loss: 2.668
# [Epoch 4, Step    26] loss: 2.624
# [Epoch 5, Step    13] loss: 2.614
# [Epoch 5, Step    26] loss: 2.239
# [Epoch 6, Step    13] loss: 2.247
# [Epoch 6, Step    26] loss: 2.286
# [Epoch 7, Step    13] loss: 2.168
# [Epoch 7, Step    26] loss: 1.914
# [Epoch 8, Step    13] loss: 1.909
# [Epoch 8, Step    26] loss: 1.753
# [Epoch 9, Step    13] loss: 1.755
# [Epoch 9, Step    26] loss: 1.789
# [Epoch 10, Step    13] loss: 1.429
# [Epoch 10, Step    26] loss: 1.513
# [Epoch 11, Step    13] loss: 1.409
# [Epoch 11, Step    26] loss: 1.430
# [Epoch 12, Step    13] loss: 1.251
# [Epoch 12, Step    26] loss: 1.321
# [Epoch 13, Step    13] loss: 1.237
# [Epoch 13, Step    26] loss: 1.223
# [Epoch 14, Step    13] loss: 1.188
# [Epoch 14, Step    26] loss: 0.977
# [Epoch 15, Step    13] loss: 1.176
# [Epoch 15, Step    26] loss: 0.976
# [Epoch 16, Step    13] loss: 0.957
# [Epoch 16, Step    26] loss: 1.069
# [Epoch 17, Step    13] loss: 0.949
# [Epoch 17, Step    26] loss: 0.814
# [Epoch 18, Step    13] loss: 1.001
# [Epoch 18, Step    26] loss: 0.811
# [Epoch 19, Step    13] loss: 0.756
# [Epoch 19, Step    26] loss: 0.892
# [Epoch 20, Step    13] loss: 0.866
# [Epoch 20, Step    26] loss: 0.841

# %%
test(test_loader, model, nn.CrossEntropyLoss())
# Out:
# Test Error:
# Accuracy: 48.3%, Avg loss: 2.736922

# %% [markdown]
# # ResNet101

# %%
#Used resnet 101 instead of resnet 152
model = models.resnet101(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /root/.cache/torch/hub/checkpoints/resnet101-5d3b4d8f.pth
#   0%|          | 0.00/170M [00:00<?, ?B/s]

# %%
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
#create new fully connected layer which is the initially features 1000 but i need 29 features so i set this value.
new_fc = torch.nn.Sequential(
    nn.Linear(in_features=2048, out_features=1000, bias=True),
    nn.ReLU(inplace=True),
    nn.Linear(in_features=1000, out_features=29, bias=True),
)

# %%
#As usal replace new fully connected layer
model.fc = new_fc

# %%
criterion = nn.CrossEntropyLoss()
optimizer = Adam(model.parameters(), lr=0.0001)

# %%
epochs = 5

for e in range(epochs):
    running_loss = 0.0
    for i, (imgs, labels) in enumerate(train_loader):
        outputs = model(imgs)
        loss = criterion(outputs, labels)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        if i % 13 == 12:
            print('[Epoch %d, Step %5d] loss: %.3f' %
                  (e + 1, i + 1, running_loss / 12))
            running_loss = 0.0
#As usal i want the result after 13 mini-batch so I have set 13 in condition and set 5 iteration.
# Out:
# [Epoch 1, Step    13] loss: 3.439
# [Epoch 1, Step    26] loss: 2.664
# [Epoch 2, Step    13] loss: 1.399
# [Epoch 2, Step    26] loss: 0.551
# [Epoch 3, Step    13] loss: 0.198
# [Epoch 3, Step    26] loss: 0.105
# [Epoch 4, Step    13] loss: 0.059
# [Epoch 4, Step    26] loss: 0.063
# [Epoch 5, Step    13] loss: 0.055
# [Epoch 5, Step    26] loss: 0.069

# %%
test(test_loader, model, nn.CrossEntropyLoss())
# Out:
# Test Error:
# Accuracy: 93.1%, Avg loss: 0.234341
